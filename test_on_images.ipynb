# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src import detect_faces, show_bboxes
from PIL import Image

# %%
img = Image.open('images/office1.jpg')
bounding_boxes, landmarks = detect_faces(img)
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# /home/juan/dev/mtcnn-pytorch/src/first_stage.py:32: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(torch.FloatTensor(_preprocess(img)), volatile=True)
# /home/juan/dev/mtcnn-pytorch/src/get_nets.py:70: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# /home/juan/dev/mtcnn-pytorch/src/detector.py:79: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img_boxes = Variable(torch.FloatTensor(img_boxes), volatile=True)
# /home/juan/dev/mtcnn-pytorch/src/get_nets.py:115: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# /home/juan/dev/mtcnn-pytorch/src/detector.py:100: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img_boxes = Variable(torch.FloatTensor(img_boxes), volatile=True)
# /home/juan/dev/mtcnn-pytorch/src/get_nets.py:168: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# <PIL.Image.Image image mode=RGB size=899x399 at 0x7F6F3246C358>

# %%
img = Image.open('images/office2.jpg')
bounding_boxes, landmarks = detect_faces(img)
show_bboxes(img, bounding_boxes, landmarks)

# %%
img = Image.open('images/office3.jpg')
bounding_boxes, landmarks = detect_faces(img)
show_bboxes(img, bounding_boxes, landmarks)

# %%
img = Image.open('images/office4.jpg')
bounding_boxes, landmarks = detect_faces(img, thresholds=[0.6, 0.7, 0.85])
show_bboxes(img, bounding_boxes, landmarks)

# %%
img = Image.open('images/office5.jpg')
bounding_boxes, landmarks = detect_faces(img, min_face_size=10.0)
show_bboxes(img, bounding_boxes, landmarks)
